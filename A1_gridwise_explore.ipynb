# %% [markdown]
# Data Exploration ---> basic overview

# %%
#Importing Package
#importing
import numpy as np
import pandas as pd
from datetime import datetime, timedelta, timezone
import matplotlib.pyplot as plt
import os
print("all libraries are loaded!")
# Out:
# all libraries are loaded!

# %%
folder_1 = 'pit-2019' #2019 and 2020
filename = "gw-geo-pit-mar-nov-2019-000000000000.csv" #from 00 to 99
df = pd.read_csv(folder_1 + '\\' + filename)
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                    driver_id  shift_id      timestamp  \
# 0       e8ebb4f5-29b5-4b69-a396-321eaed16ca1  292723.0  1567900143002
# 1       90827868-094b-4bdd-b685-86394ec67462  376787.0  1567901956165
# 2       8ce77e03-6f7d-41e6-9268-4578c983c876  375295.0  1567897565000
# 3       aacd9707-a6a2-42cf-9884-3217581db4f8  376533.0  1567901158000
# 4       90827868-094b-4bdd-b685-86394ec67462  376787.0  1567903726188
# ...                                      ...       ...            ...
# 950485  e1185941-ef6c-442d-83bd-4d524bf26b0f  496009.0  1573258778999
# 950486  b9cc3ae4-1231-4b29-b5f4-9ec817f8dbe5  495417.0  1573257566999
# 950487  17db834b-f22e-4241-a89e-933b1c0bb530   73506.0  1573259188000
# ...

# %%
df["DateTime"] = pd.to_datetime(df['timestamp'], unit='ms' , origin='unix')
df.head()
# Out:
#                               driver_id  shift_id      timestamp        lat  \
# 0  e8ebb4f5-29b5-4b69-a396-321eaed16ca1  292723.0  1567900143002  40.448278
# 1  90827868-094b-4bdd-b685-86394ec67462  376787.0  1567901956165  40.429006
# 2  8ce77e03-6f7d-41e6-9268-4578c983c876  375295.0  1567897565000  40.443489
# 3  aacd9707-a6a2-42cf-9884-3217581db4f8  376533.0  1567901158000  40.448051
# 4  90827868-094b-4bdd-b685-86394ec67462  376787.0  1567903726188  40.443242
#
#          lon  accuracy  speed  heading  altitude activity_type  \
# 0 -79.942602      12.4   9.41   173.85     275.9    in_vehicle
# 1 -79.998342      16.2   5.90   267.78     254.0    in_vehicle
# 2 -79.998225       7.5   6.07   338.00     186.0    in_vehicle
# 3 -80.002660       6.2   4.86   171.00     182.1    in_vehicle
# 4 -79.994261      12.2   5.89   205.29     229.7    in_vehicle
#
#    activity_confidence                DateTime
# 0                  100 2019-09-07 23:49:03.002
# ...

# %%
# Distribution of DateTime
print(df["DateTime"].describe())
ax = df["DateTime"].hist(bins = 90, figsize=(16, 4.5)) #March April May June July August September October November
ax.set_xlabel("DateTime")
ax.set_ylabel("Occurrence")
# Out:
# <ipython-input-76-71a1420e23b0>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(df["DateTime"].describe())
# count                         950490
# unique                        934187
# top       2019-11-11 21:29:36.242000
# freq                             469
# first     2019-03-15 00:00:01.999000
# last      2019-11-14 23:59:45.001000
# Name: DateTime, dtype: object
# Text(0, 0.5, 'Occurrence')

# %%
#driver_id
print(df["driver_id"].describe())
# Out:
# count                                   950490
# unique                                    2039
# top       4c5fae49-857f-45cb-bdf7-ac3b6f2e33ac
# freq                                     12720
# Name: driver_id, dtype: object

# %%
# accuracy
print(df["accuracy"].describe())
ax = df["accuracy"].hist(bins = 90, figsize=(8, 4.5))
ax.set_xlabel("accuracy")
ax.set_ylabel("Occurrence")
# Out:
# count    950490.000000
# mean         16.641887
# std         197.781795
# min           0.000000
# 25%           4.900000
# 50%           5.000000
# 75%          10.000000
# max      149000.000000
# Name: accuracy, dtype: float64
# Text(0, 0.5, 'Occurrence')

# %%
# speed 
# Unit??? Email Matt
print(df["speed"].describe())
ax = df["speed"].hist(bins = 90, figsize=(8, 4.5))
ax.set_xlabel("speed")
ax.set_ylabel("Occurrence")
# Out:
# count    950490.000000
# mean         14.114970
# std           9.344778
# min          -1.000000
# 25%           7.080000
# 50%          13.250000
# 75%          20.610000
# max         238.860000
# Name: speed, dtype: float64
# Text(0, 0.5, 'Occurrence')

# %%
# Heading
print(df["heading"].describe())
ax = df["heading"].hist(bins = 90, figsize=(8, 4.5))
ax.set_xlabel("heading")
ax.set_ylabel("Occurrence")
# Out:
# count    950490.000000
# mean        173.628388
# std         108.037791
# min          -1.000000
# 25%          81.720000
# 50%         169.980000
# 75%         269.730000
# max         360.000000
# Name: heading, dtype: float64
# Text(0, 0.5, 'Occurrence')

# %%
# altitude
print(df["altitude"].describe())
ax = df["altitude"].hist(bins = 90, figsize=(8, 4.5))
ax.set_xlabel("altitude")
ax.set_ylabel("Occurrence")
# Out:
# count    950490.000000
# mean        282.445394
# std          59.881908
# min        -450.000000
# 25%         237.300000
# 50%         282.300000
# 75%         325.200000
# max       12470.600000
# Name: altitude, dtype: float64
# Text(0, 0.5, 'Occurrence')

# %%
# activity_type
print(df["activity_type"].describe())
ax = df["activity_type"].hist(figsize=(8, 4.5))
ax.set_xlabel("activity_type")
ax.set_ylabel("Occurrence")
# Out:
# count         950490
# unique             7
# top       in_vehicle
# freq          814267
# Name: activity_type, dtype: object
# Text(0, 0.5, 'Occurrence')

# %%
# activity_confidence
print(df["activity_confidence"].describe())
ax = df["activity_confidence"].hist(bins = 100, figsize=(8, 4.5))
ax.set_xlabel("activity_confidence")
ax.set_ylabel("Occurrence")
# Out:
# count    950490.000000
# mean         97.366688
# std          11.304794
# min          21.000000
# 25%         100.000000
# 50%         100.000000
# 75%         100.000000
# max         100.000000
# Name: activity_confidence, dtype: float64
# Text(0, 0.5, 'Occurrence')

# %%
fig, ax = plt.subplots(figsize=(8, 8))
plt.scatter(x=df['lon'], y=df['lat'], )
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")

#plt.show()
# Out:
# Text(0, 0.5, 'Latitude')

# %% [markdown]
# Ok that was overall, but now let's explore individually for a day.

# %%
#lets pick a driver_id of the df
example_person = df['driver_id'][1]
df_indi = df[df['driver_id']== example_person]
df_indi
# Out:
#                                    driver_id  shift_id      timestamp  \
# 1       90827868-094b-4bdd-b685-86394ec67462  376787.0  1567901956165
# 4       90827868-094b-4bdd-b685-86394ec67462  376787.0  1567903726188
# 6       90827868-094b-4bdd-b685-86394ec67462  376787.0  1567899261006
# 8       90827868-094b-4bdd-b685-86394ec67462  376787.0  1567902309179
# 61      90827868-094b-4bdd-b685-86394ec67462  385925.0  1568380307009
# ...                                      ...       ...            ...
# 950001  90827868-094b-4bdd-b685-86394ec67462       NaN  1573570687002
# 950066  90827868-094b-4bdd-b685-86394ec67462  432421.0  1570639852003
# 950067  90827868-094b-4bdd-b685-86394ec67462  432421.0  1570640788999
# 950306  90827868-094b-4bdd-b685-86394ec67462  427112.0  1570369463000
# 950308  90827868-094b-4bdd-b685-86394ec67462       NaN  1573479239000
#
#               lat        lon  accuracy  speed  heading  altitude  \
# ...

# %%
#pick a single date
example_date = df_indi['DateTime'].dt.strftime('%Y-%m-%d')
example_date = example_date[1]
print(example_date)

# filter by single day
df_indi = df_indi[(df_indi['DateTime'].dt.date.astype(str) == example_date)]
df_indi
# Out:
# 2019-09-08
#                                    driver_id  shift_id      timestamp  \
# 1       90827868-094b-4bdd-b685-86394ec67462  376787.0  1567901956165
# 4       90827868-094b-4bdd-b685-86394ec67462  376787.0  1567903726188
# 8       90827868-094b-4bdd-b685-86394ec67462  376787.0  1567902309179
# 11863   90827868-094b-4bdd-b685-86394ec67462  376787.0  1567915995169
# 13765   90827868-094b-4bdd-b685-86394ec67462  376787.0  1567915331170
# 14515   90827868-094b-4bdd-b685-86394ec67462  376787.0  1567915602172
# 24760   90827868-094b-4bdd-b685-86394ec67462  376787.0  1567902137170
# 28054   90827868-094b-4bdd-b685-86394ec67462  376787.0  1567902074173
# 28551   90827868-094b-4bdd-b685-86394ec67462  376787.0  1567901144015
# 28554   90827868-094b-4bdd-b685-86394ec67462  376787.0  1567904552201
# 28555   90827868-094b-4bdd-b685-86394ec67462  376787.0  1567903764191
# 107368  90827868-094b-4bdd-b685-86394ec67462    376787  1567914072166
# ...

# %%
# To Create Directory If Not Exist
# https://appdividend.com/2021/07/03/how-to-create-directory-if-not-exist-in-python/
path = folder_1+'\\'+example_date
os.makedirs(path, exist_ok=False)
print("The new directory is created!")

#export
df_indi.to_csv(path+ "\\" + example_person + ".csv")
# Out:
# The new directory is created!
